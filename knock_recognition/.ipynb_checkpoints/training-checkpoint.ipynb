# %%
import os
import re
import numpy as np
import scipy

# Tensorflow.
import tensorflow as tf
import tensorflow_io as tfio
from tensorflow.keras import layers
from tensorflow.keras import models

# Preprocessing layers.
from kapre.time_frequency import STFT, Magnitude

# Audio data augmentation.
from audiomentations import Compose, AddGaussianNoise, TimeStretch, PitchShift, Shift, Gain

# Set the seed value for experiment reproducibility.
seed = 2022
tf.random.set_seed(seed)
np.random.seed(seed)

# Plotting.
import matplotlib.pyplot as plt

# Play audio. 
from IPython.display import Audio

# Progress bar
from tqdm.keras import TqdmCallback

# %%
# Load dataset.
audio_clips_folder_train = "./data/clips/train"
audio_clips_folder_val = "./data/clips/val"

train_ds = tf.keras.utils.audio_dataset_from_directory(
    audio_clips_folder_train,
    batch_size=2,
    validation_split=0,
    seed=0,
    output_sequence_length=34816,
    label_mode="categorical",
    follow_links=False
)

val_ds = tf.keras.utils.audio_dataset_from_directory(
    audio_clips_folder_val,
    batch_size=2,
    validation_split=0,
    seed=0,
    output_sequence_length=34816,
    label_mode="categorical",
    follow_links=False
)

class_names = np.array(train_ds.class_names)
print()
print("label names: ", class_names)
# Out:
# Found 40 files belonging to 4 classes.
# Found 12 files belonging to 4 classes.
#
# label names:  ['_silence_' 'knock_calendar' 'knock_ironlocker' 'knock_tabletop']

# %%
# Drop dimension for mono channel audios.
def squeeze(audio, labels):
    audio = tf.squeeze(audio, axis=-1)
    return audio, labels

train_ds = train_ds.map(squeeze, tf.data.AUTOTUNE)
val_ds = val_ds.map(squeeze, tf.data.AUTOTUNE)

# %%
# Check data.
for example_audios, example_labels in train_ds.take(1):
    break
print(example_audios.shape)

fig, axes = plt.subplots(nrows=1, ncols=max(2, len(example_audios)), figsize=(8, 4))
for idx, ax in enumerate(axes):
    try:
        ax.set_ylim([-0.2, 0.2])
        ax.plot(example_audios[idx])
        ax.set_title(class_names[example_labels[idx]])
    except Exception as e:
        pass
fig.tight_layout()
# Out:
# (2, 34816)

# %%
# Data augmentation. 
# Init pipeline.
augmentations_pipeline = Compose(
    [
        Shift(min_fraction=-0.3, max_fraction=0.3, p=1.0, rollover=False),
        # AddGaussianNoise(min_amplitude=0.0001, max_amplitude=0.001, p=1.0),
        # PitchShift(min_semitones=-4, max_semitones=4, p=0.5),
        # Gain(min_gain_in_db=-30.0, max_gain_in_db=0.0, p=1.0),
    ]
)

def apply_pipeline(y, sr):
    shifted = augmentations_pipeline(y, sr)
    return shifted


@tf.function
def tf_apply_pipeline(feature, sr, ):
    """
    Applies the augmentation pipeline to audio files
    @param y: audio data
    @param sr: sampling rate
    @return: augmented audio data
    """
    augmented_feature = tf.numpy_function(
        apply_pipeline, inp=[feature, sr], Tout=tf.float32, name="apply_pipeline"
    )

    return augmented_feature, sr


def augment_audio_dataset(dataset: tf.data.Dataset):
    dataset = dataset.map(tf_apply_pipeline)
    return dataset

# Apply audio augmentation.
train_ds_augmented = augment_audio_dataset(train_ds)
train_ds_augmented = train_ds_augmented.map(lambda y, sr: (tf.expand_dims(y, axis=-1), sr))
print(train_ds)
print(train_ds_augmented)
# Out:
# <ParallelMapDataset element_spec=(TensorSpec(shape=(None, 34816), dtype=tf.float32, name=None), TensorSpec(shape=(None, 4), dtype=tf.float32, name=None))>
# <MapDataset element_spec=(TensorSpec(shape=<unknown>, dtype=tf.float32, name=None), TensorSpec(shape=(None, 4), dtype=tf.float32, name=None))>

# %%
# Check data.
for example_audios, example_labels in train_ds_augmented.take(1):
    break
print(example_audios.shape)
    
fig, axes = plt.subplots(nrows=1, ncols=max(2, len(example_audios)), figsize=(16, 4))
for idx, ax in enumerate(axes):
    try:
        # ax.set_ylim([-1, 1])
        data = example_audios[idx, ::]
        # data = data / np.max(np.abs(data))
        ax.plot(data)
        ax.set_title(class_names[example_labels[idx]])
    except Exception as e:
        pass
fig.tight_layout()
# Out:
# (2, 34816, 1)

# %%
# Make spectrogram datasets.
frame_length = 1024 
frame_step = 512
def get_spectrogram(waveform):
    # Convert the waveform to a spectrogram via a STFT.
    spectrogram = tf.signal.stft(
        waveform, frame_length=frame_length, frame_step=frame_step)
    # Obtain the magnitude of the STFT.
    spectrogram = tf.abs(spectrogram)
    # Add a `channels` dimension, so that the spectrogram can be used
    # as image-like input data with convolution layers (which expect
    # shape (`batch_size`, `height`, `width`, `channels`).
    spectrogram = spectrogram[..., tf.newaxis]
    
    return spectrogram 

def make_spec_ds(ds):
    return ds.map(
        map_func=lambda audio, label: (get_spectrogram(audio), label),
        num_parallel_calls=tf.data.AUTOTUNE)
train_spectrogram_ds = make_spec_ds(train_ds_augmented)
# val_spectrogram_ds = make_spec_ds(val_ds)

# %%
# Check spectrograms. 
for example_audios, exmaple_labels in train_ds.take(1):
    break
print(example_audios.shape)
    
fig, axes = plt.subplots(nrows=1, ncols=max(2, len(example_audios)), dpi=200, figsize=(15, 10))
for idx, ax in enumerate(axes):
    try:
        # ax.set_ylim([-1, 1])
        example_spectrogram = get_spectrogram(example_audios)
        slice_size = np.array(example_spectrogram.shape)
        slice_size[2] = 200
        slice_size = [-1, -1, 100, -1]
        example_spectrogram = tf.slice(example_spectrogram, [0, 0, 0, 0], slice_size)
        print(np.shape(example_spectrogram))
        ax.imshow(example_spectrogram[idx, :, :, 0])
        ax.set_title(class_names[exmaple_labels[idx]])
    except Exception as e:
        print(e)
fig.tight_layout()
# Out:
# (2, 34816)
# (2, 67, 100, 1)
# only integers, slices (`:`), ellipsis (`...`), numpy.newaxis (`None`) and integer or boolean arrays are valid indices
# (2, 67, 100, 1)
# only integers, slices (`:`), ellipsis (`...`), numpy.newaxis (`None`) and integer or boolean arrays are valid indices

# %%
# Volume normalization. 
class VolumeNorm(layers.Layer):
    def __init__(self):
        super(VolumeNorm, self).__init__()

    def call(self, inputs):
        return inputs / tf.math.reduce_max(tf.math.abs(inputs), axis=None)

# slice layer.
class Slice(layers.Layer):
    def __init__(self, begin, size, **kwargs):
        super(Slice, self).__init__(**kwargs)
        self.begin = begin
        self.size = size
    def get_config(self):

        config = super().get_config().copy()
        config.update({
            'begin': self.begin,
            'size': self.size,
        })
        return config
    def call(self, inputs):
        return tf.slice(inputs, self.begin, self.size)

# %%
# Build model.
for examples_audios, examples_labels in train_ds_augmented.take(1):
    break
# input_shape = example_spectrograms.shape[1:]
input_shape = examples_audios.shape[1:]
print('Input shape:', input_shape)
num_categories = len(class_names)

# Instantiate the `tf.keras.layers.Normalization` layer.
norm_layer = layers.Normalization()
# Fit the state of the layer to the spectrograms
# with `Normalization.adapt`.
# norm_layer.adapt(data=train_ds_augmented.map(map_func=lambda spec, label: spec))

model = models.Sequential([
    layers.Input(shape=input_shape),
    VolumeNorm(),
    # norm_layer,
    # Compute spectrogram.
    STFT(n_fft=frame_length, win_length=frame_length, hop_length=frame_step, 
         input_data_format="channels_last",
         output_data_format="channels_last"),
    Magnitude(),
    # Remove high-frequency. 
    Slice(begin=[0, 0, 0, 0], size=[-1, -1, 200, -1]),
    # Downsample the input.
    # layers.Resizing(64, 128),
    # Normalize.
    # norm_layer,
    layers.Conv2D(32, 10, activation='relu'),
    layers.Conv2D(64, 5, activation='relu'),
    layers.MaxPooling2D(),
    # layers.Dropout(0.25),
    layers.Flatten(),
    layers.Dense(32, activation='relu'),
    # layers.Dropout(0.5),
    layers.Dense(num_categories),
    layers.Softmax()
])

model.summary()
# Out:
# Input shape: (34816, 1)
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  volume_norm (VolumeNorm)    (None, 34816, 1)          0
#
#  stft (STFT)                 (None, 67, 513, 1)        0
#
#  magnitude (Magnitude)       (None, 67, 513, 1)        0
#
#  slice (Slice)               (None, 67, 200, 1)        0
#
#  conv2d (Conv2D)             (None, 58, 191, 32)       3232
#
#  conv2d_1 (Conv2D)           (None, 54, 187, 64)       51264
#
#  max_pooling2d (MaxPooling2D  (None, 27, 93, 64)       0
#  )
#
#  flatten (Flatten)           (None, 160704)            0
#
#  dense (Dense)               (None, 32)                5142560
#
#  dense_1 (Dense)             (None, 4)                 132
#
#  softmax (Softmax)           (None, 4)                 0
#
# =================================================================
# Total params: 5,197,188
# Trainable params: 5,197,188
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Config model.
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4),
    # optimizer=tf.keras.optimizers.SGD(learning_rate=1e-4, momentum=0.1),
    # loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False),
    loss=tf.keras.losses.CategoricalCrossentropy(from_logits=False),
    metrics=['accuracy'],
)

# %%
# Training.
EPOCHS = 100
history = model.fit(
    # train_spectrogram_ds,
    train_ds_augmented,
    # validation_data=val_spectrogram_ds,
    validation_data=val_ds,
    epochs=EPOCHS,
    # callbacks=tf.keras.callbacks.EarlyStopping(verbose=1, patience=2),
    callbacks=[TqdmCallback(verbose=1)],
    verbose=0
)
# Out:
# 0epoch [00:00, ?epoch/s]
# 0batch [00:00, ?batch/s]

# %%
# Plot trainning history.
metrics = history.history
plt.figure(figsize=(16,6))
plt.subplot(1,2,1)
plt.plot(history.epoch, metrics['loss'], metrics['val_loss'])
plt.legend(['loss', 'val_loss'])
plt.ylim([0, max(plt.ylim())])
plt.xlabel('Epoch')
plt.ylabel('Loss [CrossEntropy]')

plt.subplot(1,2,2)
plt.plot(history.epoch, 100*np.array(metrics['accuracy']), 100*np.array(metrics['val_accuracy']))
plt.legend(['accuracy', 'val_accuracy'])
plt.ylim([-1, 101])
plt.xlabel('Epoch')
plt.ylabel('Accuracy [%]')
# Out:
# Text(0, 0.5, 'Accuracy [%]')

# %%
model.evaluate(val_ds, return_dict=True)
predictions = []
labels = []
for examples_audios, examples_labels in val_ds:
    predictions += list(model.predict(examples_audios, verbose=0))
    labels += list(examples_labels.numpy())
outputs = class_names[np.array(predictions).argmax(axis=-1)]
list(zip(outputs, labels))
# Out:
# 6/6 [==============================] - 0s 19ms/step - loss: 0.1964 - accuracy: 1.0000
# [('_silence_', array([1., 0., 0., 0.], dtype=float32)),
#  ('_silence_', array([1., 0., 0., 0.], dtype=float32)),
#  ('knock_ironlocker', array([0., 0., 1., 0.], dtype=float32)),
#  ('knock_tabletop', array([0., 0., 0., 1.], dtype=float32)),
#  ('knock_calendar', array([0., 1., 0., 0.], dtype=float32)),
#  ('_silence_', array([1., 0., 0., 0.], dtype=float32)),
#  ('knock_calendar', array([0., 1., 0., 0.], dtype=float32)),
#  ('knock_ironlocker', array([0., 0., 1., 0.], dtype=float32)),
#  ('knock_tabletop', array([0., 0., 0., 1.], dtype=float32)),
#  ('knock_calendar', array([0., 1., 0., 0.], dtype=float32)),
#  ('knock_ironlocker', array([0., 0., 1., 0.], dtype=float32)),
#  ('knock_tabletop', array([0., 0., 0., 1.], dtype=float32))]

# %%
examples_audios
# Out:
# <tf.Tensor: shape=(2, 34816), dtype=float32, numpy=
# array([[ 0.00131226,  0.00134277,  0.00137329, ..., -0.01547241,
#         -0.01599121, -0.01647949],
#        [ 0.00177002,  0.00177002,  0.00177002, ..., -0.00469971,
#         -0.00473022, -0.00473022]], dtype=float32)>

# %%
plt.plot(examples_audios.numpy().flatten())

# %%
# Prediting stream.
# Stream file.
# audio_filename = "./data/raw/knock_ironlocker.wav"
# audio_filename = "./data/raw/knock_ironlocker_2.wav"
# audio_filename = "./data/raw/knock_calendar.wav"
audio_filename = "./data/raw/oculus/knock_ironlocker.mp3"
# audio_filename = "./data/raw/knock_tabletop.wav"
# audio_filename = "./data/raw/oculus/knock_tabletop.mp3"
audio = tfio.audio.AudioIOTensor(audio_filename)
print(audio)
audio_tensor = tf.squeeze(audio[:], axis=[-1])
audio_float = audio_tensor / (2**15)
# audio_float = audio_float / tf.math.reduce_max(tf.math.abs(audio_float)) * 0.2

# Parameters. 
sampling_rate = audio.rate.numpy()
window_size = 34816
stride_sec = 0.8
stride_size = int(sampling_rate * stride_sec)

# Sliding window.
frames = tf.signal.frame(audio_float, frame_length=window_size, frame_step=stride_size, pad_end=True, pad_value=0)
frames = tf.expand_dims(frames, axis=-1)
# Calculate spectrogram.
# spectrogram = get_spectrogram(frames)

# Run prediction.
# predictions = model.predict(tf.expand_dims(spectrogram, axis=0))
# predictions = model.predict(spectrogram)
predictions = model.predict(frames)
outputs = class_names[tf.argmax(predictions, axis=-1)]
print(outputs)
# Out:
# <AudioIOTensor: shape=[1086336       1], dtype=<dtype: 'float32'>, rate=48000>
# 1/1 [==============================] - 0s 166ms/step
# ['_silence_' '_silence_' 'knock_ironlocker' '_silence_' '_silence_'
#  '_silence_' 'knock_ironlocker' '_silence_' '_silence_' '_silence_'
#  'knock_ironlocker' '_silence_' '_silence_' '_silence_' 'knock_ironlocker'
#  '_silence_' '_silence_' '_silence_' 'knock_ironlocker' '_silence_'
#  '_silence_' '_silence_' 'knock_ironlocker' '_silence_' '_silence_'
#  'knock_ironlocker' '_silence_' '_silence_' '_silence_']

# %%
# Plot results.
fig, ax = plt.subplots(figsize=(15, 5))

# Plot waveform.
ax.plot(audio_float.numpy())

# Plot segmentations.
start_index_arr = np.arange(0, len(audio_float), stride_size, dtype=int)
ax.vlines(start_index_arr, ymin=-0.5, ymax=0.5, color="red")

# Adding labels.
for idx, output in enumerate(outputs):
    ax.text(start_index_arr[idx], 0, output, rotation="vertical")
print(audio_float.numpy())
# Out:
# [0. 0. 0. ... 0. 0. 0.]

# %%
# Show all slices. 
ncols = 5
nrows = int(np.ceil(frames.shape[0] / ncols))
fig, axes = plt.subplots(nrows=nrows, ncols=ncols, figsize=(ncols * 3, nrows * 3), dpi=100)
axes = axes.flatten()
for idx, frame in enumerate(frames):
    # set axis.
    ax = axes[idx]
    # ax.set_ylim([-1, 1])
    ax.set_title(outputs[idx] + str(np.max(predictions[idx])))
    # frame = frame / np.max(np.abs(frame))
    ax.plot(frame)
fig.tight_layout()

# %%
# Fetch the Keras session and save the model
# The signature definition is defined by the input and output tensors,
# and stored with the default serving key
MODEL_DIR = "./model/"
version = 1
export_path = os.path.join(MODEL_DIR, str(version))
print('export_path = {}\n'.format(export_path))

tf.keras.models.save_model(
    model,
    export_path,
    overwrite=True,
    include_optimizer=True,
    save_format=None,
    signatures=None,
    options=None
)

print('\nSaved model:')
# Out:
# export_path = ./model/1
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: ./model/1\assets
# INFO:tensorflow:Assets written to: ./model/1\assets
# Saved model:

# %%
with open("./data/sample.txt", "w") as f:
    # f.write(str(frames[1].numpy().tolist()))
    f.write(str(np.rot90(frames[6]).tolist()))
